# %% [markdown]
# # Error analysis
# Reads error artifacts produced by `analyze-errors`.

# %%
from pathlib import Path
import pandas as pd
path = Path('../../artifacts/full/remote-full/reports/errors.parquet')
errors = pd.read_parquet(path) if path.exists() else pd.DataFrame()
errors['error_type'].value_counts() if not errors.empty else 'Run analyze-errors first.'
