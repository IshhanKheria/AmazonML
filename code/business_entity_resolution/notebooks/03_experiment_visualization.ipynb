# %% [markdown]
# # Experiment visualization
# Loads measured experiment logs and does not fabricate scores.

# %%
from pathlib import Path
import pandas as pd
log = pd.read_csv(Path('../../../experiments/experiment_log.tsv'), sep='\t')
log.tail()
