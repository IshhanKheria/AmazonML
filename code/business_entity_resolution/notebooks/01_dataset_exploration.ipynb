# %% [markdown]
# # Dataset exploration
# Thin client of production audit/data modules. Set `BER_DATA_ROOT` first.

# %%
import os
from business_entity_resolution.audit import audit_dataset
report = audit_dataset(os.environ['BER_DATA_ROOT'], max_rows=50_000)
report
