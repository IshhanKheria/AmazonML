# %% [markdown]
# # Baseline analysis
# Runs only the reusable synthetic smoke fixture by default.

# %%
from pathlib import Path
from business_entity_resolution.pipeline import run_smoke
report = run_smoke(Path('../../artifacts/notebook-smoke'))
report
